# %%
# Import the required packages
import os
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
from sklearn.utils import resample
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'
pd.set_option('display.max_rows', 20000)
pd.set_option('display.max_columns', 20000)
pd.set_option('display.max_colwidth', -1)
import warnings
warnings.filterwarnings("ignore")
import datetime
# Out:
# <ipython-input-1-1e9fd325078d>:13: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)

# %%
def transform_data(train_data_fname, test_data_fname):
    df_train = pd.read_csv(train_data_fname)
    df_train['is_train_set'] = 1
    df_test = pd.read_csv(test_data_fname)
    df_test['is_train_set'] = 0
    
    # Comienzo con los datos de TRAIN
    # -------------------------------------------------------------------------
    
    # Elimino los datos que tienen Nan en el Department Description
    clean_df = df_train.dropna(subset=['DepartmentDescription'])

    # Los datos que tienen Nan en Upc son todos de Pharmacy RX
    # Luego los completo con esos valores, obtenidos por inspección
    clean_df.loc[clean_df.Upc.isna(), "FinelineNumber"] = 4822
    clean_df.loc[clean_df.Upc.isna(), "Upc"] = 30169183702
    
#    unique_tt = df_train.TripType.unique()
#    lista_df = []
#    for i in unique_tt:
#        iterator = clean_df[clean_df.TripType == i]
#        max = iterator.Upc.value_counts().idxmax()
#        iterator.Upc = max
#        lista_df.append(iterator)

    unique_vn = df_train.VisitNumber.unique()
    lista_df = []
    for i in unique_vn:
        iterator = clean_df[clean_df.VisitNumber == i]
        max = iterator.Upc.max()
        iterator.Upc = max
        lista_df.append(iterator)


    df_total = pd.concat(lista_df)
    df_total = df_total.drop(["FinelineNumber"], axis=1)
    y = df_total.groupby(["VisitNumber", "Weekday"], as_index=False).max().TripType

    df_total = df_total.drop("TripType", axis=1)
    
    # VISITNUMBER, DEPARTMENT, UPC, WEEKDAY
    
    #--------------------------------------------------------------------------
    
    df_test.loc[df_test.DepartmentDescription.isna(), "Upc"] = 0
    df_test.loc[df_test.Upc.isna(), "Upc"] = 30169183702
    unique_vn = df_test.VisitNumber.unique()
    lista_df = []
    for i in unique_vn:
        iterator = df_test[df_test.VisitNumber == i]
        max = iterator.Upc.max()
        iterator.Upc = max
        lista_df.append(iterator)

    test_total = pd.concat(lista_df)
    
    test_total = test_total.drop(["FinelineNumber"], axis=1)
    
    # VISITNUMBER, DEPARTMENT, UPC, WEEKDAY
    
    temp_concat = pd.concat([df_total, test_total])
    temp_concat = pd.get_dummies(temp_concat, columns=["DepartmentDescription"], dummy_na=True)
    temp_concat = temp_concat.groupby(["VisitNumber", "Weekday", "Upc"], as_index=False).sum()
    
    temp_concat = pd.get_dummies(temp_concat, columns=["Weekday"], dummy_na=True)
    
    df_train = temp_concat[temp_concat.is_train_set != 0]
    df_test = temp_concat[temp_concat.is_train_set == 0]

    X = df_train.drop(["is_train_set"], axis=1)
    yy = None
    XX = df_test.drop(["is_train_set"], axis=1)


    return X, y, XX, yy

# %%
X, y, XX, yy = transform_data("../data/train.csv", "../data/test.csv")

# %%
from sklearn.model_selection import train_test_split
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
results = pd.DataFrame(columns=('clf', 'best_acc'))

# %%
X_train
# Out:
#        VisitNumber           Upc  ScanCount  DepartmentDescription_1-HR PHOTO  \
# 16430  32945        7.650110e+09  4          0
# 67689  135532       4.897014e+11  11         0
# 38646  77378        6.460077e+10  3          0
# 17535  35152        7.874206e+09 -4          0
# 47984  96227        6.053886e+10  6          0
# ...      ...                 ... ..         ..
# 52968  106308       8.860280e+10  15         0
# 8813   17484        1.292628e+09  1          0
# 78351  156816       1.484474e+09  1          0
# 1230   2407         6.811316e+10  2          0
# 22593  45413        7.874211e+09  3          0
#
#        DepartmentDescription_ACCESSORIES  DepartmentDescription_AUTOMOTIVE  \
# 16430  0                                  0
# 67689  0                                  0
# 38646  0                                  0
# 17535  0                                  0
# 47984  0                                  0
# ...   ..                                 ..
# 52968  0                                  0
# 8813   0                                  0
# 78351  0                                  0
# 1230   0                                  0
# 22593  0                                  0
#
#        DepartmentDescription_BAKERY  DepartmentDescription_BATH AND SHOWER  \
# 16430  0                             0
# 67689  0                             0
# 38646  0                             0
# 17535  0                             0
# 47984  0                             0
# ...   ..                            ..
# 52968  0                             0
# 8813   0                             0
# 78351  0                             0
# 1230   0                             0
# 22593  0                             0
#
#        DepartmentDescription_BEAUTY  DepartmentDescription_BEDDING  \
# 16430  0                             0
# 67689  2                             0
# 38646  0                             0
# 17535  0                             0
# 47984  0                             0
# ...   ..                            ..
# 52968  0                             0
# 8813   0                             0
# 78351  0                             0
# 1230   0                             0
# 22593  0                             0
#
#        DepartmentDescription_BOOKS AND MAGAZINES  \
# 16430  0
# 67689  0
# 38646  0
# 17535  0
# 47984  0
# ...   ..
# 52968  0
# 8813   0
# 78351  0
# 1230   0
# 22593  0
#
#        DepartmentDescription_BOYS WEAR  \
# 16430  0
# 67689  0
# 38646  0
# 17535  0
# 47984  0
# ...   ..
# 52968  0
# 8813   0
# 78351  0
# 1230   0
# 22593  0
#
#        DepartmentDescription_BRAS & SHAPEWEAR  \
# 16430  0
# 67689  0
# 38646  3
# 17535  0
# 47984  0
# ...   ..
# 52968  0
# 8813   0
# 78351  0
# 1230   0
# 22593  0
#
#        DepartmentDescription_CAMERAS AND SUPPLIES  \
# 16430  0
# 67689  0
# 38646  0
# 17535  0
# 47984  0
# ...   ..
# 52968  0
# 8813   0
# 78351  0
# 1230   0
# 22593  0
#
#        DepartmentDescription_CANDY, TOBACCO, COOKIES  \
# 16430  0
# 67689  0
# 38646  0
# 17535  0
# 47984  0
# ...   ..
# 52968  0
# 8813   0
# 78351  0
# 1230   0
# 22593  0
#
#        DepartmentDescription_CELEBRATION  DepartmentDescription_COMM BREAD  \
# 16430  0                                  0
# 67689  0                                  1
# 38646  0                                  0
# 17535  0                                  0
# 47984  0                                  0
# ...   ..                                 ..
# 52968  0                                  2
# 8813   0                                  0
# 78351  0                                  0
# 1230   0                                  0
# 22593  0                                  2
#
#        DepartmentDescription_CONCEPT STORES  \
# 16430  0
# 67689  0
# 38646  0
# 17535  0
# 47984  0
# ...   ..
# 52968  0
# 8813   0
# 78351  0
# 1230   0
# 22593  0
#
#        DepartmentDescription_COOK AND DINE  DepartmentDescription_DAIRY  \
# 16430  0                                    0
# 67689  0                                    0
# 38646  0                                    0
# 17535  0                                    0
# 47984  0                                    1
# ...   ..                                   ..
# 52968  0                                    4
# 8813   0                                    0
# 78351  0                                    0
# 1230   0                                    0
# 22593  0                                    0
#
#        DepartmentDescription_DSD GROCERY  DepartmentDescription_ELECTRONICS  \
# 16430  0                                  0
# 67689  0                                  0
# 38646  0                                  0
# 17535  3                                  0
# 47984  3                                  0
# ...   ..                                 ..
# 52968  2                                  0
# 8813   0                                  0
# 78351  0                                  0
# 1230   0                                  0
# 22593  1                                  0
#
#        DepartmentDescription_FABRICS AND CRAFTS  \
# 16430  0
# 67689  0
# 38646  0
# 17535  0
# 47984  0
# ...   ..
# 52968  0
# 8813   0
# 78351  0
# 1230   0
# 22593  0
#
#        DepartmentDescription_FINANCIAL SERVICES  \
# 16430  0
# 67689  0
# 38646  0
# 17535  0
# 47984  1
# ...   ..
# 52968  0
# 8813   0
# 78351  0
# 1230   2
# 22593  0
#
#        DepartmentDescription_FROZEN FOODS  DepartmentDescription_FURNITURE  \
# 16430  0                                   0
# 67689  0                                   0
# 38646  0                                   0
# 17535  0                                   0
# 47984  0                                   0
# ...   ..                                  ..
# 52968  0                                   0
# 8813   0                                   0
# 78351  0                                   0
# 1230   0                                   0
# 22593  0                                   0
#
#        DepartmentDescription_GIRLS WEAR, 4-6X  AND 7-14  \
# 16430  0
# 67689  0
# 38646  0
# 17535  0
# 47984  0
# ...   ..
# 52968  0
# 8813   0
# 78351  0
# 1230   0
# 22593  0
#
#        DepartmentDescription_GROCERY DRY GOODS  \
# 16430  0
# 67689  0
# 38646  0
# 17535  0
# 47984  0
# ...   ..
# 52968  2
# 8813   0
# 78351  0
# 1230   0
# 22593  0
#
#        DepartmentDescription_HARDWARE  \
# 16430  0
# 67689  0
# 38646  0
# 17535  0
# 47984  0
# ...   ..
# 52968  0
# 8813   0
# 78351  0
# 1230   0
# 22593  0
#
#        DepartmentDescription_HEALTH AND BEAUTY AIDS  \
# 16430  0
# 67689  0
# 38646  0
# 17535  0
# 47984  0
# ...   ..
# 52968  0
# 8813   0
# 78351  0
# 1230   0
# 22593  0
#
#        DepartmentDescription_HOME DECOR  \
# 16430  0
# 67689  0
# 38646  0
# 17535  0
# 47984  0
# ...   ..
# 52968  0
# 8813   0
# 78351  0
# 1230   0
# 22593  0
#
#        DepartmentDescription_HOME MANAGEMENT  \
# 16430  0
# 67689  0
# 38646  0
# 17535  0
# 47984  0
# ...   ..
# 52968  0
# 8813   0
# 78351  0
# 1230   0
# 22593  0
#
#        DepartmentDescription_HORTICULTURE AND ACCESS  \
# 16430  0
# 67689  0
# 38646  0
# 17535  0
# 47984  0
# ...   ..
# 52968  0
# 8813   0
# 78351  0
# 1230   0
# 22593  0
#
#        DepartmentDescription_HOUSEHOLD CHEMICALS/SUPP  \
# 16430  1
# 67689  1
# 38646  0
# 17535  0
# 47984  0
# ...   ..
# 52968  1
# 8813   0
# 78351  0
# 1230   0
# 22593  0
#
#        DepartmentDescription_HOUSEHOLD PAPER GOODS  \
# 16430  1
# 67689  0
# 38646  0
# 17535  0
# 47984  0
# ...   ..
# 52968  0
# 8813   0
# 78351  0
# 1230   0
# 22593  0
#
#        DepartmentDescription_IMPULSE MERCHANDISE  \
# 16430  0
# 67689  0
# 38646  0
# 17535  0
# 47984  0
# ...   ..
# 52968  0
# 8813   0
# 78351  0
# 1230   0
# 22593  0
#
#        DepartmentDescription_INFANT APPAREL  \
# 16430  0
# 67689  0
# 38646  0
# 17535  0
# 47984  0
# ...   ..
# 52968  0
# 8813   0
# 78351  0
# 1230   0
# 22593  0
#
#        DepartmentDescription_INFANT CONSUMABLE HARDLINES  \
# 16430  0
# 67689  0
# 38646  0
# 17535  0
# 47984  0
# ...   ..
# 52968  1
# 8813   0
# 78351  0
# 1230   0
# 22593  0
#
#        DepartmentDescription_JEWELRY AND SUNGLASSES  \
# 16430  0
# 67689  0
# 38646  0
# 17535  0
# 47984  0
# ...   ..
# 52968  0
# 8813   0
# 78351  1
# 1230   0
# 22593  0
#
#        DepartmentDescription_LADIES SOCKS  DepartmentDescription_LADIESWEAR  \
# 16430  0                                   0
# 67689  0                                   0
# 38646  0                                   0
# 17535  0                                   0
# 47984  0                                   0
# ...   ..                                  ..
# 52968  0                                   0
# 8813   0                                   0
# 78351  0                                   0
# 1230   0                                   0
# 22593  0                                   0
#
#        DepartmentDescription_LARGE HOUSEHOLD GOODS  \
# 16430  0
# 67689  0
# 38646  0
# 17535  0
# 47984  0
# ...   ..
# 52968  0
# 8813   0
# 78351  0
# 1230   0
# 22593  0
#
#        DepartmentDescription_LAWN AND GARDEN  \
# 16430  0
# 67689  0
# 38646  0
# 17535  0
# 47984  0
# ...   ..
# 52968  0
# 8813   0
# 78351  0
# 1230   0
# 22593  0
#
#        DepartmentDescription_LIQUOR,WINE,BEER  \
# 16430  0
# 67689  0
# 38646  0
# 17535  0
# 47984  0
# ...   ..
# 52968  0
# 8813   0
# 78351  0
# 1230   0
# 22593  0
#
#        DepartmentDescription_MEAT - FRESH & FROZEN  \
# 16430  0
# 67689  0
# 38646  0
# 17535  0
# 47984  0
# ...   ..
# 52968  0
# 8813   0
# 78351  0
# 1230   0
# 22593  0
#
#        DepartmentDescription_MEDIA AND GAMING  \
# 16430  0
# 67689  0
# 38646  0
# 17535  0
# 47984  0
# ...   ..
# 52968  0
# 8813   0
# 78351  0
# 1230   0
# 22593  0
#
#        DepartmentDescription_MENS WEAR  DepartmentDescription_MENSWEAR  \
# 16430  0                                0
# 67689  0                                0
# 38646  0                                0
# 17535  0                                0
# 47984  0                                0
# ...   ..                               ..
# 52968  1                                0
# 8813   0                                0
# 78351  0                                0
# 1230   0                                0
# 22593  0                                0
#
#        DepartmentDescription_OFFICE SUPPLIES  \
# 16430  0
# 67689  1
# 38646  0
# 17535  0
# 47984  0
# ...   ..
# 52968  0
# 8813   0
# 78351  0
# 1230   0
# 22593  0
#
#        DepartmentDescription_OPTICAL - FRAMES  \
# 16430  0
# 67689  0
# 38646  0
# 17535  0
# 47984  0
# ...   ..
# 52968  0
# 8813   0
# 78351  0
# 1230   0
# 22593  0
#
#        DepartmentDescription_OPTICAL - LENSES  \
# 16430  0
# 67689  0
# 38646  0
# 17535  0
# 47984  0
# ...   ..
# 52968  0
# 8813   0
# 78351  0
# 1230   0
# 22593  0
#
#        DepartmentDescription_OTHER DEPARTMENTS  \
# 16430  0
# 67689  0
# 38646  0
# 17535  0
# 47984  0
# ...   ..
# 52968  0
# 8813   0
# 78351  0
# 1230   0
# 22593  0
#
#        DepartmentDescription_PAINT AND ACCESSORIES  \
# 16430  0
# 67689  0
# 38646  0
# 17535  0
# 47984  0
# ...   ..
# 52968  0
# 8813   0
# 78351  0
# 1230   0
# 22593  0
#
#        DepartmentDescription_PERSONAL CARE  \
# 16430  0
# 67689  3
# 38646  0
# 17535  0
# 47984  0
# ...   ..
# 52968  0
# 8813   0
# 78351  0
# 1230   0
# 22593  0
#
#        DepartmentDescription_PETS AND SUPPLIES  \
# 16430  0
# 67689  0
# 38646  0
# 17535  0
# 47984  0
# ...   ..
# 52968  0
# 8813   0
# 78351  0
# 1230   0
# 22593  0
#
#        DepartmentDescription_PHARMACY OTC  DepartmentDescription_PHARMACY RX  \
# 16430  0                                   0
# 67689  1                                   0
# 38646  0                                   0
# 17535  0                                   0
# 47984  1                                   0
# ...   ..                                  ..
# 52968  0                                   0
# 8813   0                                   0
# 78351  0                                   0
# 1230   0                                   0
# 22593  0                                   0
#
#        DepartmentDescription_PLAYERS AND ELECTRONICS  \
# 16430  0
# 67689  0
# 38646  0
# 17535  0
# 47984  0
# ...   ..
# 52968  0
# 8813   0
# 78351  0
# 1230   0
# 22593  0
#
#        DepartmentDescription_PLUS AND MATERNITY  \
# 16430  0
# 67689  0
# 38646  0
# 17535  0
# 47984  0
# ...   ..
# 52968  0
# 8813   0
# 78351  0
# 1230   0
# 22593  0
#
#        DepartmentDescription_PRE PACKED DELI  DepartmentDescription_PRODUCE  \
# 16430  0                                      0
# 67689  0                                      0
# 38646  0                                      0
# 17535  0                                      0
# 47984  0                                      0
# ...   ..                                     ..
# 52968  0                                      2
# 8813   0                                      0
# 78351  0                                      0
# 1230   0                                      0
# 22593  0                                      0
#
#        DepartmentDescription_SEAFOOD  DepartmentDescription_SEASONAL  \
# 16430  0                              0
# 67689  0                              0
# 38646  0                              0
# 17535  0                              0
# 47984  0                              0
# ...   ..                             ..
# 52968  0                              0
# 8813   0                              0
# 78351  0                              0
# 1230   0                              0
# 22593  0                              0
#
#        DepartmentDescription_SERVICE DELI  \
# 16430  0
# 67689  0
# 38646  0
# 17535  0
# 47984  0
# ...   ..
# 52968  0
# 8813   0
# 78351  0
# 1230   0
# 22593  0
#
#        DepartmentDescription_SHEER HOSIERY  DepartmentDescription_SHOES  \
# 16430  0                                    0
# 67689  0                                    0
# 38646  0                                    0
# 17535  0                                    0
# 47984  0                                    0
# ...   ..                                   ..
# 52968  0                                    0
# 8813   0                                    1
# 78351  0                                    0
# 1230   0                                    0
# 22593  0                                    0
#
#        DepartmentDescription_SLEEPWEAR/FOUNDATIONS  \
# 16430  0
# 67689  0
# 38646  0
# 17535  0
# 47984  0
# ...   ..
# 52968  0
# 8813   0
# 78351  0
# 1230   0
# 22593  0
#
#        DepartmentDescription_SPORTING GOODS  \
# 16430  1
# 67689  0
# 38646  0
# 17535  0
# 47984  0
# ...   ..
# 52968  0
# 8813   0
# 78351  0
# 1230   0
# 22593  0
#
#        DepartmentDescription_SWIMWEAR/OUTERWEAR  DepartmentDescription_TOYS  \
# 16430  0                                         0
# 67689  0                                         0
# 38646  0                                         0
# 17535  0                                         0
# 47984  0                                         0
# ...   ..                                        ..
# 52968  0                                         0
# 8813   0                                         0
# 78351  0                                         0
# 1230   0                                         0
# 22593  0                                         0
#
#        DepartmentDescription_WIRELESS  DepartmentDescription_nan  \
# 16430  0                               0
# 67689  0                               0
# 38646  0                               0
# 17535  0                               0
# 47984  0                               0
# ...   ..                              ..
# 52968  0                               0
# 8813   0                               0
# 78351  0                               0
# 1230   0                               0
# 22593  0                               0
#
#        Weekday_Friday  Weekday_Monday  Weekday_Saturday  Weekday_Sunday  \
# 16430  0               0               0                 0
# 67689  1               0               0                 0
# 38646  0               0               0                 0
# 17535  0               0               0                 0
# 47984  0               0               1                 0
# ...   ..              ..              ..                ..
# 52968  0               0               0                 1
# 8813   0               0               0                 1
# 78351  0               0               0                 0
# 1230   1               0               0                 0
# 22593  1               0               0                 0
#
#        Weekday_Thursday  Weekday_Tuesday  Weekday_Wednesday  Weekday_nan
# 16430  0                 0                1                  0
# 67689  0                 0                0                  0
# 38646  0                 0                1                  0
# 17535  0                 0                1                  0
# 47984  0                 0                0                  0
# ...   ..                ..               ..                 ..
# 52968  0                 0                0                  0
# 8813   0                 0                0                  0
# 78351  0                 1                0                  0
# 1230   0                 0                0                  0
# 22593  0                 0                0                  0
#
# [46841 rows x 80 columns]

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score
from sklearn.naive_bayes import MultinomialNB

clf = MultinomialNB().fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-84842f05c1b8> in <module>
#       6 from sklearn.naive_bayes import MultinomialNB
#       7
# ----> 8 clf = MultinomialNB().fit(X_train, y_train)
#
# ~\Miniconda3\envs\mentoria\lib\site-packages\sklearn\naive_bayes.py in fit(self, X, y, sample_weight)
#     639
#     640         self._init_counters(n_effective_classes, n_features)
# --> 641         self._count(X, Y)
#     642         alpha = self._check_alpha()
#     643         self._update_feature_log_prob(alpha)
#
# ~\Miniconda3\envs\mentoria\lib\site-packages\sklearn\naive_bayes.py in _count(self, X, Y)
#     761     def _count(self, X, Y):
#     762         """Count and smooth feature occurrences."""
# --> 763         check_non_negative(X, "MultinomialNB (input X)")
#     764         self.feature_count_ += safe_sparse_dot(Y.T, X)
#     765         self.class_count_ += Y.sum(axis=0)
#
# ~\Miniconda3\envs\mentoria\lib\site-packages\sklearn\utils\validation.py in check_non_negative(X, whom)
#    1045
#    1046     if X_min < 0:
# -> 1047         raise ValueError("Negative values in data passed to %s" % whom)
#    1048
#    1049
#
# ValueError: Negative values in data passed to MultinomialNB (input X)

# %%
print(classification_report(y_valid, clf.predict(X_valid)))
# Out:
# Best SGDC accuracy:  0.6134796409183801
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('SGDClassifier',
#                  SGDClassifier(loss='log', n_jobs=-1, random_state=0))])
# The best classifier so far is:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('SGDClassifier',
#                  SGDClassifier(loss='log', n_jobs=-1, random_state=0))])

# %%
X.shape, XX.shape
# Out:
# ((66917, 80), (28645, 80))

# %%
yy = results.clf.iloc[0].predict(XX)

# %%
submission = pd.DataFrame(list(zip(XX.VisitNumber, yy)), columns=["VisitNumber", "TripType"])

# %%
submission.to_csv("submission_sgd.csv", header=True, index=False)
